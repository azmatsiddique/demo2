# %% [markdown]
# ## Chest X-Ray Images using CNN Model

# %% [markdown]
# ### About Dataset
#
# * The dataset consists of training data, validation data, and testing data.
# * The training data consists of 5,216 chest x-ray images with 3,875 images shown to have pneumonia and 1,341 images shown to be normal.
# * The validation data is relatively small with only 16 images with 8 cases of pneumonia and 8 normal cases.
# * The testing data consists of 624 images split between 390 pneumonia cases and 234 normal cases.

# %% [markdown]
# ### What is Pneumonia?
#
# Pneumonia is an infection in one or both lungs. Bacteria, viruses, and fungi cause it. The infection causes inflammation in the air sacs in your lungs, which are called alveoli. The alveoli fill with fluid or pus, making it difficult to breathe.
#
# ![](https://d16qt3wv6xm098.cloudfront.net/I7a1xCoDRliAGg8FBvnVZFTITK2Ao3wY/_.jpg)

# %% [markdown]
# ### Import libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Input, layers
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.core import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint


import os
import numpy as np
import pandas as np
import seaborn as sns

from random import randint
from PIL import Image

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.10.8)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! kaggle datasets download paultimothymooney/chest-xray-pneumonia
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading chest-xray-pneumonia.zip to /content
# 100% 2.29G/2.29G [00:26<00:00, 28.0MB/s]
# 100% 2.29G/2.29G [00:26<00:00, 93.4MB/s]

# %%
import os
import zipfile
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
local_zip = '/content/chest-xray-pneumonia.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %% [markdown]
# ### Load the data

# %%
main_dir = "/tmp/chest_xray/chest_xray/"
train_data_dir = main_dir + "train/"
validation_data_dir = main_dir + "val/"
test_data_dir = main_dir + "test/"

nb_train_samples = 5216
nb_validation_samples = 16
epochs = 30
batch_size = 64

print("Working Directory Contents:", os.listdir(main_dir))
# Out:
# Working Directory Contents: ['train', '.DS_Store', 'test', 'val']

# %%
train_n = train_data_dir+'NORMAL/'
train_p = train_data_dir+'PNEUMONIA/'

print("length of cases in training set:",len(os.listdir(train_p)) + len(os.listdir(train_n)))
print("length of pneumonia cases in training set:",len(os.listdir(train_p)))
print("length of normal cases in training set:",len(os.listdir(train_n)))
# Out:
# length of cases in training set: 5218
# length of pneumonia cases in training set: 3876
# length of normal cases in training set: 1342

# %%
# Quick look to the images 

img_name = 'IM-0115-0001.jpeg'
img_normal = load_img('/tmp/chest_xray/train/NORMAL/' + img_name)

img_name_1 = 'person1000_bacteria_2931.jpeg'
img_pneumonia = load_img('/tmp/chest_xray/train/PNEUMONIA/' + img_name_1)

fig, axs = plt.subplots(1,2,figsize=(10,6))
axs[0].imshow(img_normal)
axs[0].set_title("NORMAL")
axs[1].imshow(img_pneumonia)
axs[1].set_title("PNEUMONIA");

# %% [markdown]
# The actual sizes of the photos are so high that I set them to size 180x180.

# %%
img_height, img_width  = 180, 180


if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)

# %% [markdown]
# ### Upload images

# %%
# Performing Image Augmentation to have more data samples

train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1. / 255)
val_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')

validation_generator = val_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary')

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
# Show some images after data augmentation

image_batch, label_batch = next(iter(train_generator))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10, 10))
    for n in range(15):
        ax = plt.subplot(5, 5, n + 1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch, label_batch)

# %% [markdown]
# Model 1

# %% [markdown]
# ### Build the CNN

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape, padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3),  activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 180, 180, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 64)                1982528
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 2,011,233
# Trainable params: 2,011,233
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %% [markdown]
# ### Callbacks
#
# * EarlyStopping (Stop training when a monitored metric has stopped improving)
#
# * ReduceLROnPlateau (Reduce learning rate when a metric has stopped improving)
#
# * ModelCheckpoint (Callback to save the Keras model or model weights at some frequency)

# %%
# Define the callbacks

callbacks1 = [ 
    EarlyStopping(monitor = 'loss', patience = 6), 
    ReduceLROnPlateau(monitor = 'loss', patience = 3), 
    ModelCheckpoint('../working/model.best3.hdf5',monitor='loss', save_best_only=True) # saving the best model
]

# %% [markdown]
# ### Correct for the imbalance

# %% [markdown]
# Data is imbalanced, with more images classified as pneumonia than normal. We will correct for that by using class weighting

# %%
count_normal = len(train_n)
count_pneumonia = len(train_p)

initial_bias = count_pneumonia / count_normal
print("Initial bias: {:.5f}".format(initial_bias))

TRAIN_IMG_COUNT = count_normal + count_pneumonia
weight_for_0 = (1 / count_normal) * (TRAIN_IMG_COUNT) / 2.0
weight_for_1 = (1 / count_pneumonia) * (TRAIN_IMG_COUNT) / 2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print("Weight for class 0: {:.2f}".format(weight_for_0))
print("Weight for class 1: {:.2f}".format(weight_for_1))
# Out:
# Initial bias: 1.07500
# Weight for class 0: 1.04
# Weight for class 1: 0.97

# %%
METRICS = [tf.keras.metrics.BinaryAccuracy(),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall")]

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=METRICS)

# %% [markdown]
# ### Fit the model

# %%
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    callbacks=callbacks1)
    #class_weight=class_weight)
# Out:
# Epoch 1/30
# 82/82 [==============================] - 123s 1s/step - loss: 0.5055 - binary_accuracy: 0.7797 - precision: 0.8164 - recall: 0.9076 - val_loss: 0.3765 - val_binary_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 0.0010
# Epoch 2/30
# 82/82 [==============================] - 90s 1s/step - loss: 0.3174 - binary_accuracy: 0.8715 - precision: 0.9027 - recall: 0.9270 - val_loss: 1.1479 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000 - lr: 0.0010
# Epoch 3/30
# 82/82 [==============================] - 91s 1s/step - loss: 0.2707 - binary_accuracy: 0.8903 - precision: 0.9249 - recall: 0.9277 - val_loss: 0.3420 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000 - lr: 0.0010
# Epoch 4/30
# 82/82 [==============================] - 92s 1s/step - loss: 0.2379 - binary_accuracy: 0.9062 - precision: 0.9343 - recall: 0.9399 - val_loss: 0.3883 - val_binary_accuracy: 0.8750 - val_precision: 0.8000 - val_recall: 1.0000 - lr: 0.0010
# Epoch 5/30
# 82/82 [==============================] - 92s 1s/step - loss: 0.2128 - binary_accuracy: 0.9128 - precision: 0.9387 - recall: 0.9443 - val_loss: 0.6302 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000 - lr: 0.0010
# Epoch 6/30
# 82/82 [==============================] - 93s 1s/step - loss: 0.2016 - binary_accuracy: 0.9208 - precision: 0.9457 - recall: 0.9479 - val_loss: 1.4561 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000 - lr: 0.0010
# Epoch 7/30
# 82/82 [==============================] - 92s 1s/step - loss: 0.1970 - binary_accuracy: 0.9248 - precision: 0.9469 - recall: 0.9523 - val_loss: 0.8618 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000 - lr: 0.0010
# Epoch 8/30
# 82/82 [==============================] - 93s 1s/step - loss: 0.1836 - binary_accuracy: 0.9339 - precision: 0.9551 - recall: 0.9559 - val_loss: 0.5701 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000 - lr: 0.0010
# Epoch 9/30
# 82/82 [==============================] - 92s 1s/step - loss: 0.1703 - binary_accuracy: 0.9417 - precision: 0.9605 - recall: 0.9610 - val_loss: 0.4755 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000 - lr: 0.0010
# Epoch 10/30
# 82/82 [==============================] - 93s 1s/step - loss: 0.1641 - binary_accuracy: 0.9419 - precision: 0.9601 - recall: 0.9618 - val_loss: 0.2956 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000 - lr: 0.0010
# Epoch 11/30
# 82/82 [==============================] - 89s 1s/step - loss: 0.1600 - binary_accuracy: 0.9417 - precision: 0.9589 - recall: 0.9628 - val_loss: 0.7663 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000 - lr: 0.0010
# Epoch 12/30
# 82/82 [==============================] - 89s 1s/step - loss: 0.1594 - binary_accuracy: 0.9457 - precision: 0.9631 - recall: 0.9639 - val_loss: 0.1386 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - lr: 0.0010
# Epoch 13/30
# 82/82 [==============================] - 88s 1s/step - loss: 0.1506 - binary_accuracy: 0.9465 - precision: 0.9651 - recall: 0.9628 - val_loss: 0.3283 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000 - lr: 0.0010
# Epoch 14/30
# 82/82 [==============================] - 90s 1s/step - loss: 0.1543 - binary_accuracy: 0.9469 - precision: 0.9629 - recall: 0.9657 - val_loss: 0.3603 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000 - lr: 0.0010
# Epoch 15/30
# 82/82 [==============================] - 90s 1s/step - loss: 0.1440 - binary_accuracy: 0.9477 - precision: 0.9659 - recall: 0.9636 - val_loss: 0.6745 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000 - lr: 0.0010
# Epoch 16/30
# 82/82 [==============================] - 91s 1s/step - loss: 0.1426 - binary_accuracy: 0.9505 - precision: 0.9672 - recall: 0.9662 - val_loss: 0.2782 - val_binary_accuracy: 0.8750 - val_precision: 0.8000 - val_recall: 1.0000 - lr: 0.0010
# Epoch 17/30
# 82/82 [==============================] - 91s 1s/step - loss: 0.1626 - binary_accuracy: 0.9507 - precision: 0.9684 - recall: 0.9652 - val_loss: 0.4878 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000 - lr: 0.0010
# Epoch 18/30
# 82/82 [==============================] - 90s 1s/step - loss: 0.1353 - binary_accuracy: 0.9557 - precision: 0.9698 - recall: 0.9706 - val_loss: 1.7700 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000 - lr: 0.0010
# Epoch 19/30
# 82/82 [==============================] - 89s 1s/step - loss: 0.1375 - binary_accuracy: 0.9511 - precision: 0.9665 - recall: 0.9677 - val_loss: 2.0725 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000 - lr: 0.0010
# Epoch 20/30
# 82/82 [==============================] - 90s 1s/step - loss: 0.1388 - binary_accuracy: 0.9525 - precision: 0.9670 - recall: 0.9690 - val_loss: 0.5622 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000 - lr: 0.0010
# Epoch 21/30
# 82/82 [==============================] - 92s 1s/step - loss: 0.1333 - binary_accuracy: 0.9534 - precision: 0.9705 - recall: 0.9667 - val_loss: 1.1281 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000 - lr: 0.0010
# Epoch 22/30
# 82/82 [==============================] - 93s 1s/step - loss: 0.1355 - binary_accuracy: 0.9544 - precision: 0.9705 - recall: 0.9680 - val_loss: 0.4379 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000 - lr: 0.0010
# Epoch 23/30
# 82/82 [==============================] - 93s 1s/step - loss: 0.1290 - binary_accuracy: 0.9578 - precision: 0.9721 - recall: 0.9711 - val_loss: 0.2887 - val_binary_accuracy: 0.8750 - val_precision: 0.8000 - val_recall: 1.0000 - lr: 0.0010
# Epoch 24/30
# 82/82 [==============================] - 93s 1s/step - loss: 0.1273 - binary_accuracy: 0.9571 - precision: 0.9704 - recall: 0.9719 - val_loss: 0.7591 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000 - lr: 0.0010
# Epoch 25/30
# 82/82 [==============================] - 92s 1s/step - loss: 0.1217 - binary_accuracy: 0.9590 - precision: 0.9729 - recall: 0.9719 - val_loss: 0.5522 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000 - lr: 0.0010
# Epoch 26/30
# 82/82 [==============================] - 91s 1s/step - loss: 0.1309 - binary_accuracy: 0.9594 - precision: 0.9753 - recall: 0.9698 - val_loss: 0.2257 - val_binary_accuracy: 0.8750 - val_precision: 0.8000 - val_recall: 1.0000 - lr: 0.0010
# Epoch 27/30
# 82/82 [==============================] - 92s 1s/step - loss: 0.1190 - binary_accuracy: 0.9597 - precision: 0.9727 - recall: 0.9732 - val_loss: 0.2813 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000 - lr: 0.0010
# Epoch 28/30
# 82/82 [==============================] - 90s 1s/step - loss: 0.1262 - binary_accuracy: 0.9595 - precision: 0.9710 - recall: 0.9747 - val_loss: 0.1522 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - lr: 0.0010
# Epoch 29/30
# 82/82 [==============================] - 90s 1s/step - loss: 0.1260 - binary_accuracy: 0.9571 - precision: 0.9709 - recall: 0.9714 - val_loss: 0.2423 - val_binary_accuracy: 0.8750 - val_precision: 0.8000 - val_recall: 1.0000 - lr: 0.0010
# Epoch 30/30
# 82/82 [==============================] - 90s 1s/step - loss: 0.1250 - binary_accuracy: 0.9601 - precision: 0.9744 - recall: 0.9719 - val_loss: 0.5073 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000 - lr: 0.0010

# %% [markdown]
# ### Predict and evaluate results

# %%
# Evaluate the model
scores = model.evaluate(test_generator, return_dict=True)

print(scores)
#print("Loss of the model: %.2f"%(scores[0]))
#print("Test Accuracy: %.2f%%"%(scores[1] * 100))
# Out:
# 10/10 [==============================] - 6s 645ms/step - loss: 0.6499 - binary_accuracy: 0.8846 - precision: 0.8518 - recall: 0.9872
# {'loss': 0.6498610377311707, 'binary_accuracy': 0.8846153616905212, 'precision': 0.8517699241638184, 'recall': 0.9871794581413269}

# %%
# Saving the model for future use

from keras.models import load_model

model.save('/tmp/chestxray_cnn_model_3.h5')
